# %%
a=2.3
b=5.4
c=a+b
print(c)
# Out:
# 7.7

# %%
dataset=(1)
dataset1=(2.3)
dataset2=(2+5j)
print(type(dataset))
print(type(dataset1))
print(type(dataset2))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
a=5
print(pow(5,2))
# Out:
# 25

# %%
k=10
print(pow(10,3))
# Out:
# 1000

# %%
d=15
print(pow(9,5,8))
# Out:
# 1

# %%
a=10
b=200
c=a/b
print(c)
# Out:
# 0.05

# %%
c=a//b
print(c)
# Out:
# 0

# %%
a=2+5j
b=c+3j
c=a+b
print(c)
# Out:
# (12+22j)

# %%
print(abs(-10))
# Out:
# 10

# %%
print(abs(20))
# Out:
# 20

# %%
a=15
b=23
print("Before swapping")
print(a,b)
a,b=b,a
print("After swapping ")
print(a,b)
# Out:
# Before swapping
# 15 23
# After swapping
# 23 15

# %%
import random
print(random.randrange(1,100))
# Out:
# 15

# %%
print(random.randrange(0,1))
# Out:
# 0

# %%
list=["Mango","Banana","Grapes","Pineapple","Blueberry"]
print(random.choice(list))
# Out:
# Blueberry

# %%
import math
print(math.sqrt(280))
# Out:
# 16.73320053068151

# %%
print(math.pow(5,3))
# Out:
# 125.0
